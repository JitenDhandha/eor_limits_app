# %%
import numpy as np
import importlib
import eor_limits
import plot_eor_limits
import matplotlib.pyplot as plt

# %%
importlib.reload(eor_limits)
importlib.reload(plot_eor_limits)

fig, ax = plt.subplots(figsize=(6, 6))

for dataset_name in eor_limits.get_all_dataset_names():
    print(f"Plotting dataset: {dataset_name}")
    data = eor_limits.get_dataset_lowest_limits(dataset_name)
    fig, ax = plot_eor_limits.plot(data, ax=ax, plot_type='scatter', x_axis='k',
                                   plot_kwargs={'label': f"{dataset_name}"})

ax.set_xscale('log')
fig.show()
# Out:
# Plotting dataset: Rahimi2021
# Plotting dataset: Barry2019
# Plotting dataset: Dillon2014
# Plotting dataset: Dillon2015
# Plotting dataset: Gehlot2019
# Plotting dataset: Paciga2013
# Plotting dataset: Ewall-Wice2016
# Plotting dataset: Wilensky2023
# Plotting dataset: Kolopanis2019
# Plotting dataset: Mertens2020
# Plotting dataset: Patil2017
# Plotting dataset: Eastwood2019
# Plotting dataset: Munshi2024
# Plotting dataset: Ali2015
# Plotting dataset: Acharya2024
# Plotting dataset: Gehlot2020
# Plotting dataset: Garsden2021
# Plotting dataset: HERA2022
# Plotting dataset: Mertens2025
# Plotting dataset: Trott2020
# Plotting dataset: Nunhokee2025
# Plotting dataset: Li2019
# Plotting dataset: Pal2021
# Plotting dataset: Beardsley2016
# Plotting dataset: HERA2023
# Plotting dataset: Parsons2014
# Plotting dataset: Yoshiura2021
# /var/folders/19/kzw5nz4j5d37grxxb91y_y9r0000gn/T/ipykernel_2519/1316933314.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
